# %% [markdown]
# Used to construct the images to manually count synapses in.
# Jay helped me with this.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import urllib2
from __future__ import division

np.set_printoptions(precision=3, suppress=True)
url = ('https://raw.githubusercontent.com/Upward-Spiral-Science'
       '/data/master/syn-density/output.csv')
data = urllib2.urlopen(url)
csv = np.genfromtxt(data, delimiter=",")[1:]

def check_condition(row):
    if row[3] == 0:
        return False
    return True

a = np.apply_along_axis(check_condition, 1, csv)
a = np.where(a == True)[0]
nonZeroMask = csv[a, :]

cleaned = nonZeroMask[nonZeroMask[:,0] >= 409]
cleaned = cleaned[cleaned[:,0] <= 3529]
cleaned = cleaned[cleaned[:,1] >= 1564]
cleaned = cleaned[cleaned[:,1] <= 3124]

# %%
from image_scraping import *

# %%
from IPython.display import Image, HTML, display

img = bin_to_nparray(cleaned[2000,1],cleaned[2000,2])
plt.figure(figsize=(5, 5), frameon=False)
plt.imshow(img, cmap='Greys_r')
plt.axis('off')
plt.show()

# %%
args += [True]
img_max_overlay = bin_to_nparray(cleaned[2000,1],cleaned[2000,2])
plt.figure(figsize=(5, 5), frameon=False)
plt.imshow(img_max_overlay, cmap='Greys_r')
plt.axis('off')
plt.show()

# %%
stacked = img_max_overlay[:,:,-1]+img*.5
plt.figure(figsize=(5, 5), frameon=False)
plt.imshow(stacked, cmap='Greys_r')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-44-70c277475e44> in <module>()
# ----> 1 stacked = img_max_overlay[:,:,-1]+img*.5
#       2 plt.figure(figsize=(5, 5), frameon=False)
#       3 plt.imshow(stacked, cmap='Greys_r')
#       4 plt.axis('off')
#       5 plt.show()
#
# IndexError: too many indices for array
